# %%
import numpy as np
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %% [markdown]
# # test

# %%
actions = ['좋다','예쁘다','너','나','지우기','오늘','고마워','항상','안경','책',
           '보다','먹다','자다','안녕']

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'


data_load = []
for act in actions:
    data_load.append(glob.glob(f'dataset/seq_{act}*.npy'))
np_load = []
for data in data_load:
    np_load.append(np.load(data[0]))

# %% [markdown]
# # training

# %%
import glob
import numpy as np


actions = ['좋다','예쁘다','너','나','지우기','오늘','고마워','항상','안경','책',
           '보다','먹다','자다','안녕','커피','사랑','대회','내일','노래','숙제']

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'


data_load = []
for act in actions:
    data_load.append(glob.glob(f'dataset/seq_{act}*.npy'))
np_load = []
for data in data_load:
    np_load.append(np.load(data[0]))

# %%
data = np.concatenate(np_load, axis=0)

data.shape
# Out:
# (16475, 30, 100)

# %%
x_data = data[:, :, :-1]
labels = data[:, 0, -1]

print(x_data.shape)
print(labels.shape)
# Out:
# (16475, 30, 99)
# (16475,)

# %%
from tensorflow.keras.utils import to_categorical

y_data = to_categorical(labels, num_classes=len(actions))
y_data.shape
# Out:
# (16475, 20)

# %%
from sklearn.model_selection import train_test_split

x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)

x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.2, random_state=2023)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (13180, 30, 99) (13180, 20)
# (3295, 30, 99) (3295, 20)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D
import tensorflow as tf

# model = Sequential([
#     LSTM(64, activation='relu', input_shape=x_train.shape[1:3]),
#     Dense(32, activation='relu'),
#     Dense(len(actions), activation='softmax')
# ])

model = Sequential([
    Conv1D(filters=32, kernel_size=5, padding='same', activation='relu', input_shape=x_train.shape[1:3]), 
    MaxPooling1D(pool_size=2),
    LSTM(64, activation='relu'),
    Dropout(0.2), 
    Dense(32, activation='relu'),
#     Dense(64, activation='relu'),
#     Dense(32, activation='relu'),
    Dense(len(actions), activation='softmax')
])


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 30, 32)            15872
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 15, 32)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 64)                24832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_51 (Dense)             (None, 20)                660
# =================================================================
# Total params: 43,444
# Trainable params: 43,444
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

history = model.fit(
    x_train,
    y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    callbacks=[
        ModelCheckpoint('models/model.h5', monitor='val_acc', verbose=1, save_best_only=True, mode='auto'),
        ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=10, verbose=1, mode='auto')
    ]
)
# Out:
# Epoch 1/50
# 410/412 [============================>.] - ETA: 0s - loss: 1.5990 - acc: 0.5296
# Epoch 00001: val_acc improved from -inf to 0.80607, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 1.5950 - acc: 0.5301 - val_loss: 0.5812 - val_acc: 0.8061
# Epoch 2/50
# 410/412 [============================>.] - ETA: 0s - loss: 0.5932 - acc: 0.7838
# Epoch 00002: val_acc improved from 0.80607 to 0.93202, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 0.5925 - acc: 0.7841 - val_loss: 0.1927 - val_acc: 0.9320
# Epoch 3/50
# 410/412 [============================>.] - ETA: 0s - loss: 0.3722 - acc: 0.8729
# Epoch 00003: val_acc improved from 0.93202 to 0.96783, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 0.3716 - acc: 0.8731 - val_loss: 0.1076 - val_acc: 0.9678
# Epoch 4/50
# 410/412 [============================>.] - ETA: 0s - loss: 0.2139 - acc: 0.9284
# Epoch 00004: val_acc did not improve from 0.96783
# 412/412 [==============================] - 3s 7ms/step - loss: 0.2134 - acc: 0.9285 - val_loss: 0.1086 - val_acc: 0.9560
# Epoch 5/50
# 404/412 [============================>.] - ETA: 0s - loss: 0.1430 - acc: 0.9506
# Epoch 00005: val_acc improved from 0.96783 to 0.98938, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 0.
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0303 - acc: 0.9927 - val_loss: 0.0051 - val_acc: 0.9976
# Epoch 38/50
# 408/412 [============================>.] - ETA: 0s - loss: 0.0179 - acc: 0.9953
# Epoch 00038: val_acc improved from 0.99848 to 0.99939, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0177 - acc: 0.9954 - val_loss: 0.0017 - val_acc: 0.9994
# Epoch 39/50
# 412/412 [==============================] - ETA: 0s - loss: 0.0584 - acc: 0.9868
# Epoch 00039: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0584 - acc: 0.9868 - val_loss: 0.0306 - val_acc: 0.9906
# Epoch 40/50
# 405/412 [============================>.] - ETA: 0s - loss: 0.0326 - acc: 0.9901
# Epoch 00040: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0327 - acc: 0.9901 - val_loss: 0.0176 - val_acc: 0.9951
# Epoch 41/50
# 410/412 [============================>.] - ETA: 0s - loss: 0.0301 - acc: 0.9918
# Epoch 00041: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0305 - acc: 0.9917 - val_loss: 0.0466 - val_acc: 0.9885
# Epoch 42/50
# 411/412 [============================>.] - ETA: 0s - loss: 0.0354 - acc: 0.9901
# Epoch 00042: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0354 - acc: 0.9901 - val_loss: 0.0179 - val_acc: 0.9939
# Epoch 43/50
# 408/412 [============================>.] - ETA: 0s - loss: 0.0335 - acc: 0.9907
# Epoch 00043: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0334 - acc: 0.9907 - val_loss: 0.0044 - val_acc: 0.9991
# Epoch 44/50
# 411/412 [============================>.] - ETA: 0s - loss: 0.0154 - acc: 0.9957
# Epoch 00044: val_acc did not improve from 0.99939
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0154 - acc: 0.9958 - val_loss: 0.0081 - val_acc: 0.9976
# Epoch 45/50
# 412/412 [==============================] - ETA: 0s - loss: 0.0134 - acc: 0.9958
# Epoch 00045: val_acc improved from 0.99939 to 0.99970, saving model to models\model.h5
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0134 - acc: 0.9958 - val_loss: 0.0037 - val_acc: 0.9997
# Epoch 46/50
# 407/412 [============================>.] - ETA: 0s - loss: 0.0259 - acc: 0.9932
# Epoch 00046: val_acc did not improve from 0.99970
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0258 - acc: 0.9933 - val_loss: 0.0239 - val_acc: 0.9939
# Epoch 47/50
# 406/412 [============================>.] - ETA: 0s - loss: 0.0117 - acc: 0.9968
# Epoch 00047: val_acc did not improve from 0.99970
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0120 - acc: 0.9967 - val_loss: 0.0075 - val_acc: 0.9979
# Epoch 48/50
# 408/412 [============================>.] - ETA: 0s - loss: 0.0108 - acc: 0.9967
# Epoch 00048: val_acc did not improve from 0.99970
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0108 - acc: 0.9967 - val_loss: 0.0052 - val_acc: 0.9982
# Epoch 49/50
# 409/412 [============================>.] - ETA: 0s - loss: 0.0140 - acc: 0.9966
# Epoch 00049: val_acc did not improve from 0.99970
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0140 - acc: 0.9965 - val_loss: 0.0053 - val_acc: 0.9991
# Epoch 50/50
# 406/412 [============================>.] - ETA: 0s - loss: 0.0315 - acc: 0.9938
# Epoch 00050: val_acc did not improve from 0.99970
# 412/412 [==============================] - 3s 7ms/step - loss: 0.0321 - acc: 0.9936 - val_loss: 0.0567 - val_acc: 0.9836

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model

model = load_model('models/model.h5')

y_pred = model.predict(x_val)

multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))
# Out:
# array([[[2937,    0],
#         [   0,  358]],
#
#        [[3117,    0],
#         [   0,  178]],
#
#        [[3101,    0],
#         [   1,  193]],
#
#        [[2975,    0],
#         [   0,  320]],
#
#        [[2956,    0],
#         [   0,  339]],
#
#        [[2850,    0],
#         [   0,  445]],
#
#        [[2839,    0],
#         [   0,  456]],
#
#        [[3001,    0],
#         [   0,  294]],
#
#        [[3027,    1],
#         [   0,  267]],
#
#        [[2851,    0],
#         [   0,  444]]], dtype=int64)
